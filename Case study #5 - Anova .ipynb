# %% [markdown]
# # Case Study on ANOVA
# #### XYZ Company has offices in four different zones. The company wishes to investigate the following :
#
# #### ● The mean sales generated by each zone.
# #### ● Total sales generated by all the zones for each month.
# #### ● Check whether all the zones generate the same amount of sales.
# #### Help the company to carry out their study with the help of data provided.

# %%
#importing data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("Sales_data_zone_wise.csv")
data.head()
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0  Month - 1   1483525   1748451   1523308   2267260
# 1  Month - 2   1238428   1707421   2212113   1994341
# 2  Month - 3   1860771   2091194   1282374   1241600
# 3  Month - 4   1871571   1759617   2290580   2252681
# 4  Month - 5   1244922   1606010   1818334   1326062

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     29 non-null     object
#  1   Zone - A  29 non-null     int64
#  2   Zone - B  29 non-null     int64
#  3   Zone - C  29 non-null     int64
#  4   Zone - D  29 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %%
#checking null values
data.isnull().sum()
# Out:
# Month       0
# Zone - A    0
# Zone - B    0
# Zone - C    0
# Zone - D    0
# dtype: int64

# %%
# to know  statistical summary  
data.describe()
# Out:
#            Zone - A      Zone - B      Zone - C      Zone - D
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06
# std    2.619401e+05  1.683899e+05  3.331937e+05  3.750165e+05
# min    1.128185e+06  1.527574e+06  1.237722e+06  1.234311e+06
# 25%    1.305972e+06  1.606010e+06  1.523308e+06  1.520406e+06
# 50%    1.534390e+06  1.740365e+06  1.767047e+06  1.854412e+06
# 75%    1.820196e+06  1.875658e+06  2.098463e+06  2.180416e+06
# max    2.004480e+06  2.091194e+06  2.290580e+06  2.364132e+06

# %% [markdown]
# ### 1 The mean sales generated by each zone.

# %%
round(data.mean(),2)
# Out:
# Zone - A    1540493.14
# Zone - B    1755559.59
# Zone - C    1772871.03
# Zone - D    1842926.76
# dtype: float64

# %% [markdown]
# ### Findings:
#
#  Zone-D has the highest mean sales.
#
#  Zone -A is having lowest mean sales.

# %% [markdown]
# ### 2 Total sales generated by all the zones for each month.

# %%
data["monthly sales(sum of all Zones)"] =data['Zone - A']+data['Zone - B']+data['Zone - C']+data['Zone - D']
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D  \
# 0    Month - 1   1483525   1748451   1523308   2267260
# 1    Month - 2   1238428   1707421   2212113   1994341
# 2    Month - 3   1860771   2091194   1282374   1241600
# 3    Month - 4   1871571   1759617   2290580   2252681
# 4    Month - 5   1244922   1606010   1818334   1326062
# 5    Month - 6   1534390   1573128   1751825   2292044
# 6    Month - 7   1820196   1992031   1786826   1688055
# 7    Month - 8   1625696   1665534   2161754   2363315
# 8    Month - 9   1652644   1873402   1755290   1422059
# 9   Month - 10   1852450   1913059   1754314   1608387
# 10  Month - 11   2004480   1740365   1317869   1970069
# 11  Month - 12   1537539   1875658   1237722   1460165
# 12  Month - 13   1254939   1588473   1348629   1733383
# 13  Month - 14   1821799   1844081   1617376   1872259
# 14  Month - 15   1128185   1804613   1767047   1234311
# 15  Month - 16   1491534   1542053   1882159   1590913
# ...

# %%
plt.figure(figsize=(17,10))
sns.barplot(data =data ,x = "Month", y = "monthly sales(sum of all Zones)",color="green")
plt.title("Total Sales by Month", fontsize = 17)
plt.xlabel("Months", fontsize=13)
plt.ylabel("Total Monthly Sale", fontsize = 13)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Highest Total Sales was generated in month-4.
#
# Lowest Total Sales was generated in month-13.

# %% [markdown]
# ### 3 Check whether all the zones generate the same amount of sales.

# %% [markdown]
# To check this One way ANOVA test can be used.
#
# Null hypothesis (Ho) : The Zones generate same amount of sales.
# Alternate hypothesis (H1) : The Zones generate different amount of sales.
#
# Let the significance level be 0.05

# %%
from scipy import stats

Fvalue, pvalue = stats.f_oneway(data['Zone - A'], data['Zone - B'], data['Zone - C'],data['Zone - D'])
print('F-value:',round(F,4),'p-value:',round(p,4))
# Out:
# F-value: 5.6721 p-value: 0.0012

# %%
alpha = 0.05
if pvalue > alpha:
    print('We Reject Null Hypothesis (Ho);The Zones generate different amount of sales')
else:
    print('We Accept Null Hypothesis (H1);The Zones generate same amount of sales')
# Out:
# We Accept Null Hypothesis (H1);The Zones generate same amount of sales

# %% [markdown]
# ### Findings:
#
# From the One-way ANOVA Test performed,
#
# p-value< 0.05
#
# So we reject the null hypothesis H0.
#
# i.e ,  all the zones does not generate the same amount of sales.
